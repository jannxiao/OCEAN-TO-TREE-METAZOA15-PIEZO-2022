# %%
# %%bash
# ### No Need to Modify ###
# wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh --quiet
# sha256sum Miniconda3-latest-Linux-x86_64.sh #should be 1314b90489f154602fd794accfc90446111514a5a72fe1f71ab83e07de9504a7
# bash Miniconda3-latest-Linux-x86_64.sh -b -p $HOME/miniconda3 > out.txt
# Out:
# 4ee9c3aa53329cd7a63b49877c0babb49b19b7e5af29807b793a76bdb1d362b4  Miniconda3-latest-Linux-x86_64.sh
# Extracting : _openmp_mutex-4.5-1_gnu.tar.bz2:  97%|█████████▋| 38/39 [00:02<00:00, 16.53it/s]

# %%
# %%bash
# ### No Need to Modify ###
# source $HOME/miniconda3/bin/activate
# conda install -c bioconda blast
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3
#
#   added / updated specs:
#     - blast
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pyopenssl-22.0.0           |     pyhd3eb1b0_0          50 KB
#     six-1.16.0                 |     pyhd3eb1b0_1          18 KB
#     sqlite-3.37.2              |       hc218d9a_0        1008 KB
#     urllib3-1.26.8             |     pyhd3eb1b0_0         106 KB
#     ------------------------------------------------------------
#                                            Total:         1.2 MB
#
# The following packages will be REMOVED:
#
#   conda-content-trust-0.1.1-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   pyopenssl                             21.0.0-pyhd3eb1b0_1 --> 22.0.0-pyhd3eb1b0_0
#   six                                   1.16.0-pyhd3eb1b0_0 --> 1.16.0-pyhd3eb1b0_1
#   sqlite                                  3.37.0-hc218d9a_0 --> 3.37.2-hc218d9a_0
#   urllib3                               1.26.7-pyhd3eb1b0_0 --> 1.26.8-pyhd3eb1b0_0
#
#
# Proceed ([y]/n)?
#
# Downloading and Extracting Packages
# pyopenssl-22.0.0     | 50 KB     | ########## | 100%
# sqlite-3.37.2        | 1008 KB   | ########## | 100%
# six-1.16.0           | 18 KB     | ########## | 100%
# urllib3-1.26.8       | 106 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# %%bash
# ### No Need to Modify ###
# source $HOME/miniconda3/bin/activate
# conda install -c bioconda mafft=7.487
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3
#
#   added / updated specs:
#     - mafft=7.487
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mafft-7.487                |       h779adbc_0         3.0 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following packages will be UPDATED:
#
#   mafft                                    7.310-h1b792b2_4 --> 7.487-h779adbc_0
#
#
# Proceed ([y]/n)?
#
# Downloading and Extracting Packages
# mafft-7.487          | 3.0 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# %%bash
# ### No Need to Modify ###
# source $HOME/miniconda3/bin/activate
# conda install -c bioconda clipkit
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3
#
#   added / updated specs:
#     - clipkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     biopython-1.78             |   py39h7f8727e_0         2.2 MB
#     blas-1.0                   |              mkl           6 KB
#     clipkit-1.3.0              |     pyhdfd78af_0          18 KB  bioconda
#     intel-openmp-2021.4.0      |    h06a4308_3561         4.2 MB
#     mkl-2021.4.0               |     h06a4308_640       142.6 MB
#     mkl-service-2.4.0          |   py39h7f8727e_0          59 KB
#     mkl_fft-1.3.1              |   py39hd3c417c_0         182 KB
#     mkl_random-1.2.2           |   py39h51133e4_0         309 KB
#     numpy-1.21.2               |   py39h20f2e39_0          23 KB
#     numpy-base-1.21.2          |   py39h79a1101_0         4.9 MB
#     ------------------------------------------------------------
#                                            Total:       154.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   biopython          pkgs/main/linux-64::biopython-1.78-py39h7f8727e_0
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   clipkit            bioconda/noarch::clipkit-1.3.0-pyhdfd78af_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2021.4.0-h06a4308_3561
#   mkl                pkgs/main/linux-64::mkl-2021.4.0-h06a4308_640
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py39h7f8727e_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.1-py39hd3c417c_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.2-py39h51133e4_0
#   numpy              pkgs/main/linux-64::numpy-1.21.2-py39h20f2e39_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.21.2-py39h79a1101_0
#
#
# Proceed ([y]/n)?
#
# Downloading and Extracting Packages
# mkl-service-2.4.0    | 59 KB     | ########## | 100%
# mkl_fft-1.3.1        | 182 KB    | ########## | 100%
# mkl-2021.4.0         | 142.6 MB  | ########## | 100%
# numpy-base-1.21.2    | 4.9 MB    | ########## | 100%
# intel-openmp-2021.4. | 4.2 MB    | ########## | 100%
# numpy-1.21.2         | 23 KB     | ########## | 100%
# clipkit-1.3.0        | 18 KB     | ########## | 100%
# biopython-1.78       | 2.2 MB    | ########## | 100%
# blas-1.0             | 6 KB      | ########## | 100%
# mkl_random-1.2.2     | 309 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# %%bash
# ### No Need to Modify ###
# source $HOME/miniconda3/bin/activate
# conda install -c bioconda iqtree
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3
#
#   added / updated specs:
#     - iqtree
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     iqtree-2.0.3               |       h176a8bc_1         3.0 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   iqtree             bioconda/linux-64::iqtree-2.0.3-h176a8bc_1
#
#
# Proceed ([y]/n)?
#
# Downloading and Extracting Packages
# iqtree-2.0.3         | 3.0 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# %%bash
# ### No Need to Modify ###
# pip install gdown --upgrade --no-cache-dir --quiet &&
# gdown --id 11S8ROPmgjhIakLOcBhz-SJ2q0-d3wTrV &&
# tar -xf 6-homologs-genes.tar.gz
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11S8ROPmgjhIakLOcBhz-SJ2q0-d3wTrV
# To: /content/6-homologs-genes/6-homologs-genes.tar.gz
# 100%|██████████| 181M/181M [00:02<00:00, 76.4MB/s]

# %%
import os
os.chdir('6-homologs-genes')

# %%
#000-group-basal-metazoans

# Nematostella vectensis
# Morbakka virulenta
# Hydra vulgaris
# Thelohanellus kitauei
# Rhopilema esculentum
# Hormiphora californensis
# Mnemiopsis leidyi
# Trichoplax adhaerens
# Ephydatia muelleri
# Amphimedon queenslandica
# Monosiga brevicollis
# Capsaspora owczarzaki
# Sphaeroforma arctica
# Homo sapiens
# Drosophila melanogaster
# Caenorhabditis elegans

# %%
# %%bash
# #001-ls-blastdbs
#
# mkdir output || echo ""
# echo
# ls -1 4-projectdb-projectdb/projectdb-fastas-provided/*aa > output/1-list-projectdb-blastdbs
# ls -1 source-rgs/rgs5-piezo-full_length-03dec2021.fasta > output/1-list-rgs

# %%
#002-python-command-blastp

# input_list
# localdb/projectdb-Metazoa-Nematoda-Chromadorea-Rhabditida-Onchocercidae-Brugia-malayi-6279-Bmal-4.0.fasta

input_list = open( 'output/1-list-projectdb-blastdbs', 'r' )
input_rgs = open( 'output/1-list-rgs', 'r' )
output_command = open( '003-blastp_X_projectDB', 'w' )

for next_rgs in input_rgs:

    rgs_fasta = next_rgs[ :-1 ] # ends up assigning to pore region in this case

for next_line in input_list:

    db_path = next_line[ :-1 ]
    info = next_line[ :-1 ].split( '-' )
    genus = info[ 10 ]
    species = info[ 11 ]
    gspp = genus + '-' + species
    
    output = 'blastp -db ' + db_path  + ' -outfmt 6 -out output/3-blast-report-rgs_X_projectdb-' + gspp + ' -max_hsps 1 -query ' + rgs_fasta + ' -evalue 1e-3\n'
    output_command.write( output )
    
output = 'echo\n'
output_command.write( output )

input_list.close()
input_rgs.close()
output_command.close()

# %%
# %%bash
# #003-blastp_X_projectDB
# source $HOME/miniconda3/bin/activate
# bash 003-blastp_X_projectDB

# %%
# %%bash
# #004-ls-reports-and-fastas
#
# ls output/3-blast-report-rgs_X_projectdb-* > output/4-list-reports
# ls 4-projectdb-projectdb/projectdb-fastas-provided/*aa > output/4-list-fastas

# %%
#005-python-gene-set-fasta

# rgs73-worm-TRPA_Cele_TRPA-TRPA2_1_481-uniprotQ21517-extraction_51_366   Metazoa-Chordata-Coelacanthimorpha-Coelacanthiformes-Coelacanthidae-Latimeria-chalumnae-pdb0000292542   26.036  169     98      4       140     299     846     996     3.39e-05        44.4

input_fastas = open( 'output/4-list-fastas', 'r' )
input_reports = open( 'output/4-list-reports', 'r' )
output_geneset_gspp = open( 'output/5-blastp-hits.fasta', 'w')
output_geneset_gspp_sub = open( 'output/5-blastp-pore-region-hits.fasta', 'w')

gene_seq = {}
gene_coordinates = {}
for next_fasta in input_fastas:
    
    fasta = next_fasta[ :-1 ]
    input_fasta = open( fasta, 'r' )
    
    for next_line in input_fasta:

        if next_line[ 0 ] == '>':
            
            header = next_line[ 1:-1 ]
            gene_seq[ header ] = ''

        else:

            sequence = next_line[ :-1 ]
            gene_seq[ header ] = gene_seq[ header ] + sequence

    input_fasta.close()

for next_report in input_reports:

    all_hits = []
    report = next_report[ :-1 ]
    input_report = open( report, 'r' )
 
    for next_line in input_report:

        report_info = next_line.split( '\t' )
        gene_id = report_info[ 1 ]
        all_hits.append( gene_id )
        coordinate_1 = int( report_info[ 8 ] ) - 1
        coordinate_2 = int( report_info[ 9 ] ) - 1
        gene_coordinates[ gene_id ] = ( coordinate_1, coordinate_2 )
        
    unique_hits = list( set( all_hits ) )

    for next_hit in unique_hits:
        
        gene_id = next_hit
        sequence = gene_seq[ gene_id ]
        coordinate_1 = gene_coordinates[ gene_id ][ 0 ]
        coordinate_2 = gene_coordinates[ gene_id ][ 1 ]
        subsequence = sequence[ coordinate_1 : coordinate_2 ] 

        output = '>' + gene_id + '\n' + sequence + '\n'
        output_geneset_gspp.write( output )
        
        output_sub = '>' + gene_id + '\n' + subsequence + '\n'
        output_geneset_gspp_sub.write( output_sub )

    input_report.close()

input_fastas.close()
input_reports.close()
output_geneset_gspp.close()
output_geneset_gspp_sub.close()

# %%
# %%bash
# #006-blastp-rgs_X_rgs-genomes
# source $HOME/miniconda3/bin/activate
#
# blastp -db 4-projectdb-projectdb/projectdb-fastas-provided/projectdb-Metazoa-Chordata-Mammalia-Primates-Hominidae-Homo-sapiens*aa -query source-rgs/rgs5-piezo-full_length-03dec2021.fasta -out output/6-blast-report-rgs5-piezo-family_X_human-genome -outfmt 6  -max_hsps 1
#
# blastp -db 4-projectdb-projectdb/projectdb-fastas-provided/projectdb-Metazoa-Arthropoda-Insecta-Diptera-Drosophilidae-Drosophila-melanogaster*aa -query source-rgs/rgs5-piezo-full_length-03dec2021.fasta -out output/6-blast-report-rgs5-piezo-family_X_fly-genome -outfmt 6  -max_hsps 1
#
# blastp -db 4-projectdb-projectdb/projectdb-fastas-provided/projectdb-Metazoa-Nematoda-Chromadorea-Rhabditida-Rhabditidae-Caenorhabditis-elegans*aa -query source-rgs/rgs5-piezo-full_length-03dec2021.fasta -out output/6-blast-report-rgs5-piezo-family_X_worm-genome -outfmt 6  -max_hsps 1

# %%
# %%bash
# #007-ls-rgs-reports-fastas
#
# ls output/6*genome* > output/7-list-reports
#
# ls 4-projectdb-projectdb/projectdb-fastas-provided/*Homo-sapiens*aa > output/7-list-rgs-projectdb-fastas
# ls 4-projectdb-projectdb/projectdb-fastas-provided/*Drosophila-melanogaster*aa >> output/7-list-rgs-projectdb-fastas
# ls 4-projectdb-projectdb/projectdb-fastas-provided/*Caenorhabditis-elegans*aa >> output/7-list-rgs-projectdb-fastas
# Out:
# ls: cannot access 'output/6*genome*': No such file or directory

# %%
#008-python-update-reference-genomes


##### USER INPUT
input_reports = open( 'output/7-list-reports', 'r' )
input_fastas = open( 'output/7-list-rgs-projectdb-fastas', 'r' )
input_rgsfasta = open( 'source-rgs/rgs5-piezo-full_length-03dec2021.fasta', 'r' )
output_map = open( 'output/8-map-source-to-reference-identifiers', 'a' )

model_species = [ 'human','mouse','fly','worm','anemone' ]

###### BEING SCRIPT 
# read in reference gene header identifier and sequence into dictionary
rgs_seq = {}
for next_line in input_rgsfasta:

    if next_line[ 0 ] == '>':

        identifier = next_line[ 1:-1 ].split( ' ' )[ 0 ]
        rgs_seq[ identifier ] = ''

    else:

        rgs_seq[ identifier ] = rgs_seq[ identifier ] + next_line[ :-1 ]

# read rgs query and rgs genome top hit into dictionary
gengene_refgene = {}
rgs_genes = []
gengenes = []

for next_report in input_reports:
    
    input_report = open( next_report[ :-1 ], 'r' )
    
    model_name = ""
    for model in model_species:
        if model in next_report:
            model_name = model
            break

    for next_hit in input_report:

        info = next_hit.split( '\t' )
        refgene = info[ 0 ]
        gengene = info[ 1 ]
        name = refgene.split( '-' )[ 1 ]
        
        if name == model_name:

            if (refgene in rgs_genes) or (gengene in gengenes):

                pass

            else:

                gengene_refgene[ gengene ] = refgene
                rgs_genes.append( refgene )
                gengenes.append( gengene )

        else:

            pass
            
    input_report.close()


# read in RGS genome and replace rgs genes (top hit in blast of rgs _X_ rgs genome) with rgs header and sequence
header_seq = {}
for next_fasta in input_fastas:

    input_fasta = open( next_fasta[ :-1 ], 'r' )
    output_name = 'output/8-' + next_fasta[ :-1 ].split( '/' )[ -1 ] + '-rgs'
    output_fasta = open( output_name, 'w' )

    for next_line in input_fasta:

        if next_line[ 0 ] == '>':

            count = 0
            
            header_info = next_line[ 1:-1 ]

            if header_info in gengene_refgene.keys():
                
                count = 1
                gengene = header_info
                refgene = gengene_refgene[ gengene ]
                
                header = '>' + refgene + '\n'
                output_fasta.write( header )

                
                output = gengene + '\t' + refgene + '\n'
                output_map.write( output )                
                
            else:

                header = next_line
                output_fasta.write( header )
                
        else:

            if count == 0:

                sequence = next_line
                output_fasta.write( sequence )

            else:

                sequence = rgs_seq[ refgene ] + '\n'
                output_fasta.write( sequence )

    input_fasta.close()
    output_fasta.close()

input_reports.close()
input_fastas.close()
input_rgsfasta.close()
output_map.close()

# %%
# %%bash
# #009-ls-reference-genome-fastas
#
# cat output/8*rgs > output/9-rgs-all-genomes-combined.fasta-rgs
# ls -1 output/9*rgs > output/9-list-RGS-header-reference-genome-fastas

# %%
#010-python-command-makeblastdb

input_list = open( 'output/9-list-RGS-header-reference-genome-fastas', 'r' )
output_makedb = open( '011-blastp-makedb', 'w' )

for next_fasta in input_list:

    fasta_path = next_fasta[ :-1 ]
    fasta = fasta_path.split( '/' )[ -1 ]
    
    db_name = fasta.split( '.' )[ 0 ] + '-AA'
    
    command = 'makeblastdb -in '  + fasta_path + ' -parse_seqids -dbtype prot'
    output = command + '\n'
    output_makedb.write( output )

input_list.close()
output_makedb.close()

# %%
# %%bash
# #011-blastp-makedb
# source $HOME/miniconda3/bin/activate
#
# bash 011-blastp-makedb
# Out:
# Building a new DB, current time: 02/18/2022 05:41:28
# New DB name:   /content/6-homologs-genes/output/9-rgs-all-genomes-combined.fasta-rgs
# New DB title:  output/9-rgs-all-genomes-combined.fasta-rgs
# Sequence type: Protein
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 53595 sequences in 2.84786 seconds.

# %%
# %%bash
# #012-ls-blastp-rgs-genomes
#
# ls -1 output/9-rgs-all-genomes-combined.fasta-rgs > output/12-list-blastp-annotated-rgs-genomes

# %%
#013-python-command-blastp

# input_list
# 11-projectdb-Homo-sapiens-cgs-AA.dmnd

input_list = open( 'output/12-list-blastp-annotated-rgs-genomes', 'r' )
output_command = open( '014-blastp-hits_X_RGS-genomes', 'w' )

output = '#! /bin/bash\n'
output_command.write( output )

for next_line in input_list:

    db_path = next_line[ :-1 ]
    info = db_path.split( '-' )
    genome = info[ -3 ] + '-' + info[ -2 ]

    output =  'blastp -db ' + db_path  + ' -outfmt 6 -out output/14-blastp-report-blastp_hits_X_RGS-genome-' + genome + '  -max_target_seqs 1 -max_hsps 1 -query output/5-blastp-pore-region-hits.fasta -matrix BLOSUM45 -evalue 1e-3 -num_threads 60 &\n'
 
    output_command.write( output )

input_list.close()
output_command.close()

# %%
# %%bash
# #014-blastp-hits_X_RGS-genomes
# source $HOME/miniconda3/bin/activate
#
# bash 014-blastp-hits_X_RGS-genomes

# %%
# %%bash
# #015-cat-all-blastp-reports
#
# cat output/14-* > output/15-all-blastp-all-reports

# %%
#016-python-RBF-CGS-each-RGS-genome-fasta


##### USER INPUT

input_fastas = open( 'output/4-list-fastas', 'r' )
input_hits = open( 'output/15-all-blastp-all-reports', 'r' )
input_rgs_ids = open( 'output/8-map-source-to-reference-identifiers', 'r' )

output_fasta = open( 'output/16-CGS-final-sequences-by-blastp-RBF.fasta', 'w' )
output_filtered = open( 'output/16-dropped-queries-no-rgs-top-hit-in-rgs-genome', 'w' )

model_species = [ 'human','mouse','fly','worm','anemone' ]

##### BEGIN SCRIPT

rgs_ids = []

for next_line in input_rgs_ids:

        info = next_line[ :-1 ].split( '\t' )
        projectdb_id = info[ 0 ]
        rgs_id = info[ 1 ]
        rgs_ids.append( rgs_id )
        rgs_ids.append( projectdb_id )

keepers = []
queries = []

for next_hit in input_hits:

        info = next_hit.split( '\t' )
        query = info[ 0 ]
        queries.append( query )
        
        hit = info[ 1 ]        
        hit_info = hit.split( '-' )
        name = hit_info[ 1 ]

        if name in model_species:
                
                # drop RGS genes
                if query in rgs_ids:

                        pass

                else:
                        keepers.append( query )

        else:
                output = query + '\t' + hit + '\n'
                output_filtered.write( output )

# produce post-filtered keepers diamond fasta NO RGS
count = 0

for next_fasta in input_fastas:

        input_fasta = open( next_fasta[ :-1 ], 'r' )

        for next_line in input_fasta:
                
                if next_line[ 0 ] == '>':
                        count = 0
                        identifier = next_line[ 1:-1 ]

                        if identifier in keepers:
                                count = 1
                                header = '>' + identifier + '\n'
                                output_fasta.write( header )
                                
                        else:
                                pass

                else:

                        if count == 0:
                                pass

                        else:

                                sequence = next_line
                                output_fasta.write( sequence )
                                
        input_fasta.close()
            
input_hits.close()
input_fastas.close()
output_fasta.close()
input_rgs_ids.close()

# %%
# %%bash
# #017-cat-RGS-CGS-fasta
#
# cat source-rgs/rgs5-piezo-full_length-03dec2021.fasta output/16-CGS-final-sequences-by-blastp-RBF.fasta > output/17-AGS_blastp-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.aa

# %%
# %%bash
# #018-sed-dashes-for-mafft-PACBIO
#
# # clean sequences for other applications
# sed -e 's/-/_/g' output/17-AGS_blastp-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.aa > output/18-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.aa
# sed -i 's/U/X/g' output/18-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.aa

# %%
# %%bash
# #019-mafft-pore-sequence-PACBIO
# source $HOME/miniconda3/bin/activate
#
# mafft --originalseqonly --maxiterate 1000 --reorder  --bl 45 --thread 40 output/18-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.aa > output/19-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.mafft
# Out:
# nthread = 40
# nthreadpair = 40
# nthreadtb = 16
# ppenalty_ex = 0
# stacksize: 8192 kb
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#     1 / 5 (thread    9)
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#     0 / 5
# done.
#
# Progressive alignment 1/2...
# STEP     3 / 4 (thread   13) f
# Reallocating..done. *alloclen = 6735
# STEP     4 / 4 (thread   14) f
# done.
#
# Making a distance matrix from msa..
#     0 / 5 (thread    1)
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#     0 / 5
# done.
#
# Progressive alignment 2/2...
# STEP     2 / 4 (thread   14) f
# Reallocating..done. *alloclen = 6536
# STEP     4 / 4 (thread   13) f
# done.
#
# disttbfast (aa) Version 7.487
# alg=A, model=BLOSUM45, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# rescale = 1
#     0 / 5 (thread    0)dndpre (aa) Version 7.487
# alg=X, model=BLOSUM45, 1.53, +0.12, -0.00, noshift, amax=0.0
# 40 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 45 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# rescale = 1
#
#     0 / 5
# Segment   1/ 21    1- 608
# 005-0006-1 (thread    1) worse
# Converged.
# Segment   2/ 21  589- 846
# 004-0006-0 (thread    5) worse
# Converged.
# Segment   3/ 21  843-1251
# 003-0006-0 (thread    5) worse
# Converged.
#
# Converged2.
# Segment   4/ 21 1248-1608
# 008-0006-1 (thread    6) identical
# Converged.
#
# Converged2.
# Segment   5/ 21 1606-1609
# 001-0003-1 (thread    5) identical
# Converged.
# Segment   6/ 21 1609-1612
# 001-0004-0 (thread    6) identical
# Converged.
# Segment   7/ 21 1612-2259
# 004-0006-1 (thread    5) worse
# Converged.
# Segment   8/ 21 2250-2325
# 002-0006-0 (thread    8) identical
# Converged.
# Segment   9/ 21 2325-2522
# 002-0003-0 (thread    4) worse
# Converged.
# Segment  10/ 21 2522-2526
# 001-0006-0 (thread    1) identical
# Converged.
# Segment  11/ 21 2526-2570
# 001-0006-0 (thread    6) identical
# Converged.
# Segment  12/ 21 2570-2575
# 001-0006-0 (thread    4) identical
# Converged.
# Segment  13/ 21 2575-2580
# 001-0006-1 (thread    5) identical
# Converged.
# Segment  14/ 21 2580-2599
# 001-0006-1 (thread    7) identical
# Converged.
# Segment  15/ 21 2599-2639
# 001-0006-0 (thread    6) identical
# Converged.
# Segment  16/ 21 2639-2674
# 001-0006-1 (thread    1) identical
# Converged.
# Segment  17/ 21 2674-2682
# 001-0006-0 (thread    6) identical
# Converged.
# Segment  18/ 21 2682-2687
# 001-0003-0 (thread    6) identical
# Converged.
# Segment  19/ 21 2687-2700
# 001-0006-1 (thread    3) identical
# Converged.
# Segment  20/ 21 2700-3141
# 003-0006-1 (thread    7) identical
# Converged.
# Segment  21/ 21 3139-3197
# 001-0006-0 (thread    6) identical
# Converged.
# done
# dvtditr (aa) Version 7.487
# alg=A, model=BLOSUM45, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  FFT-NS-i (Accurate but slow)
#  Iterative refinement method (max. 16 iterations)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.

# %%
# %%bash
# #020-clipkit-smartgap-pore-sequence_PACBIO
# source $HOME/miniconda3/bin/activate
#
# clipkit -l -m smart-gap output/19-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.mafft -o output/20-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.clipkit-smartgap
# Out:
# Determining smart-gap threshold...
#
# -------------
# | Arguments |
# -------------
# Input file: output/19-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.mafft (format: fasta)
# Output file: output/20-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.clipkit-smartgap (format: fasta)
# Gaps threshold: 0.8
# Trimming mode: smart-gap
# Create complementary output: False
# Create log file: True
#
#
# ------------------------
# | Processing Alignment |
# ------------------------
#
#
#
# ------------------------
# | Writing output files |
# ------------------------
# trimmed alignment: output/20-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.clipkit-smartgap
# complement file: False
# log file: output/20-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.clipkit-smartgap.log
#
#
# ---------------------
# | Output Statistics |
# ---------------------
# Number of sites kept: 2734
# Number of sites trimmed: 462
#
# Percentage of alignment trimmed: 14.456%
#
# Execution time: 0.179s
# 100%|██████████| 3196/3196 [00:00<00:00, 22598.83it/s]

# %%
# %%bash
# #021-iqtree2-PACBIO
# source $HOME/miniconda3/bin/activate
#
# iqtree -s output/20-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.clipkit-smartgap -m MFP --prefix output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED --rate -B 2000 -alrt 2000 -T AUTO -bnni -safe
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    d382aa18806e (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -s output/20-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.clipkit-smartgap -m MFP --prefix output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED --rate -B 2000 -alrt 2000 -T AUTO -bnni -safe
# Seed:    900385 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Fri Feb 18 05:56:01 2022
# Kernel:  Safe AVX+FMA - auto-detect threads (2 CPU cores detected)
#
# Reading alignment file output/20-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.clipkit-smartgap ... Fasta format detected
# Alignment most likely contains protein sequences
# Alignment has 5 sequences with 2734 columns, 2295 distinct patterns
# 483 parsimony-informative, 1886 singleton sites, 365 constant sites
#                                    Gap/Ambiguity  Composition  p-value
#    1  rgs5_human_PIEZO1_uniprotQ92508      8.89%    failed      0.00%
#    2  rgs5_human_PIEZO2_uniprotQ9H5I5      5.05%    failed      0.00%
#    3  rgs5_fly_Piezo_uniprotM9MSG8        10.31%    passed     44.69%
#    4  rgs5_fly_Pzl_uniprotA0A126GXQ2      16.83%    failed      0.00%
#    5  rgs5_worm_pezo1_uniprotA0A061ACX2   15.25%    passed     32.72%
# ****  TOTAL                               11.27%  3 sequences failed composition chi2 test (p-value<5%; df=19)
#
#
# Create initial parsimony tree by phylogenetic likelihood library (PLL)... 0.001 seconds
# Measuring multi-threading efficiency up to 2 CPU cores
# Increase to 10 rounds for branch lengths
# 10 trees examined
# Threads: 1 / Time: 2.162 sec / Speedup: 1.000 / Efficiency: 100% / LogL: -28710
# Threads: 2 / Time: 1.834 sec / Speedup: 1.179 / Efficiency: 59% / LogL: -28710
# BEST NUMBER OF THREADS: 2
#
# Perform fast likelihood tree search using LG+I+G model...
# Estimate model parameters (epsilon = 5.000)
# Perform nearest neighbor interchange...
# Estimate model parameters (epsilon = 1.000)
# 1. Initial log-likelihood: -27905.263
# Optimal log-likelihood: -27904.415
# Proportion of invariable sites: 0.031
# Gamma shape alpha: 2.345
# Parameters optimization took 1 rounds (0.085 sec)
# Time for fast ML tree search: 0.768 seconds
#
# NOTE: ModelFinder requires 35 MB RAM!
# ModelFinder will test up to 546 protein models (sample size: 2734) ...
#  No. Model         -LnL         df  AIC          AICc         BIC
#   1  LG            28087.037    7   56188.074    56188.115    56229.469
#   2  LG+I          27995.178    8   56006.357    56006.409    56053.665
#   3  LG+G4         27901.963    8   55819.926    55819.979    55867.234
#   4  LG+I+G4       27902.323    9   55822.646    55822.712    55875.868
#   5  LG+R2         27905.308    9   55828.617    55828.683    55881.838
#   6  LG+R3         27901.987    11  55825.975    55826.072    55891.024
#  16  LG+F+G4       27853.695    27  55761.390    55761.949    55921.055
#  17  LG+F+I+G4     27853.943    28  55763.886    55764.487    55929.465
#  29  WAG+G4        28085.541    8   56187.081    56187.134    56234.390
#  30  WAG+I+G4      28084.022    9   56186.044    56186.110    56239.266
#  42  WAG+F+G4      27914.009    27  55882.019    55882.577    56041.684
#  43  WAG+F+I+G4    27912.702    28  55881.405    55882.005    56046.983
#  55  JTT+G4        28100.000    8   56215.999    56216.052    56263.307
#  56  JTT+I+G4      28099.889    9   56217.778    56217.844    56271.000
#  68  JTT+F+G4      27969.959    27  55993.918    55994.477    56153.583
#  69  JTT+F+I+G4    27970.023    28  55996.045    55996.646    56161.624
#  81  JTTDCMut+G4   28108.230    8   56232.459    56232.512    56279.767
#  82  JTTDCMut+I+G4 28108.144    9   56234.288    56234.354    56287.510
#  94  JTTDCMut+F+G4 27973.266    27  56000.533    56001.091    56160.198
#  95  JTTDCMut+F+I+G4 27973.384    28  56002.767    56003.368    56168.346
# 107  DCMut+G4      28432.116    8   56880.232    56880.285    56927.540
# 108  DCMut+I+G4    28431.863    9   56881.726    56881.792    56934.948
# 120  DCMut+F+G4    28019.359    27  56092.719    56093.277    56252.384
# 121  DCMut+F+I+G4  28019.409    28  56094.819    56095.419    56260.397
# 133  VT+G4         27969.669    8   55955.338    55955.391    56002.646
# 134  VT+I+G4       27967.190    9   55952.379    55952.445    56005.601
# 146  VT+F+G4       27900.967    27  55855.935    55856.493    56015.600
# 147  VT+F+I+G4     27898.710    28  55853.420    55854.020    56018.998
# 159  PMB+G4        28056.541    8   56129.082    56129.135    56176.391
# 160  PMB+I+G4      28053.447    9   56124.893    56124.959    56178.115
# 172  PMB+F+G4      28014.460    27  56082.921    56083.479    56242.586
# 173  PMB+F+I+G4    28011.804    28  56079.609    56080.209    56245.187
# 185  Blosum62+G4   28045.014    8   56106.028    56106.081    56153.336
# 186  Blosum62+I+G4 28042.009    9   56102.018    56102.084    56155.239
# 198  Blosum62+F+G4 27978.038    27  56010.075    56010.634    56169.740
# 199  Blosum62+F+I+G4 27974.927    28  56005.854    56006.455    56171.433
# 211  Dayhoff+G4    28432.303    8   56880.605    56880.658    56927.913
# 212  Dayhoff+I+G4  28432.048    9   56882.097    56882.163    56935.318
# 224  Dayhoff+F+G4  28019.033    27  56092.065    56092.624    56251.730
# 225  Dayhoff+F+I+G4 28019.078    28  56094.155    56094.756    56259.734
# 237  mtREV+G4      29109.846    8   58235.692    58235.745    58283.000
# 238  mtREV+I+G4    29110.605    9   58239.210    58239.276    58292.432
# 250  mtREV+F+G4    28150.552    27  56355.103    56355.662    56514.768
# 251  mtREV+F+I+G4  28151.249    28  56358.499    56359.099    56524.077
# 263  mtART+G4      29190.857    8   58397.714    58397.767    58445.022
# 264  mtART+I+G4    29191.774    9   58401.547    58401.613    58454.769
# 276  mtART+F+G4    28229.241    27  56512.483    56513.042    56672.148
# 277  mtART+F+I+G4  28230.150    28  56516.300    56516.900    56681.878
# 289  mtZOA+G4      28786.849    8   57589.699    57589.751    57637.007
# 290  mtZOA+I+G4    28787.725    9   57593.451    57593.517    57646.672
# 302  mtZOA+F+G4    28023.627    27  56101.254    56101.813    56260.919
# 303  mtZOA+F+I+G4  28024.561    28  56105.122    56105.722    56270.701
# 315  mtMet+G4      29078.758    8   58173.516    58173.569    58220.824
# 316  mtMet+I+G4    29079.662    9   58177.324    58177.390    58230.546
# 328  mtMet+F+G4    28065.523    27  56185.047    56185.605    56344.712
# 329  mtMet+F+I+G4  28066.510    28  56189.020    56189.620    56354.598
# 341  mtVer+G4      29312.436    8   58640.872    58640.925    58688.180
# 342  mtVer+I+G4    29313.310    9   58644.620    58644.686    58697.842
# 354  mtVer+F+G4    28271.632    27  56597.263    56597.822    56756.928
# 355  mtVer+F+I+G4  28272.607    28  56601.215    56601.815    56766.793
# 367  mtInv+G4      29326.098    8   58668.197    58668.250    58715.505
# 368  mtInv+I+G4    29327.079    9   58672.159    58672.225    58725.380
# 380  mtInv+F+G4    27968.763    27  55991.527    55992.086    56151.192
# 381  mtInv+F+I+G4  27969.777    28  55995.554    55996.155    56161.133
# 393  mtMAM+G4      29392.453    8   58800.906    58800.959    58848.215
# 394  mtMAM+I+G4    29393.309    9   58804.618    58804.684    58857.839
# 406  mtMAM+F+G4    28424.033    27  56902.066    56902.625    57061.731
# 407  mtMAM+F+I+G4  28424.802    28  56905.605    56906.205    57071.183
# 419  HIVb+G4       28399.884    8   56815.769    56815.822    56863.077
# 420  HIVb+I+G4     28397.710    9   56813.420    56813.487    56866.642
# 432  HIVb+F+G4     28209.637    27  56473.275    56473.833    56632.940
# 433  HIVb+F+I+G4   28208.836    28  56473.672    56474.272    56639.251
# 445  HIVw+G4       29276.748    8   58569.496    58569.549    58616.804
# 446  HIVw+I+G4     29274.645    9   58567.290    58567.356    58620.511
# 458  HIVw+F+G4     28608.484    27  57270.968    57271.527    57430.633
# 459  HIVw+F+I+G4   28607.248    28  57270.496    57271.097    57436.075
# 471  FLU+G4        28429.132    8   56874.265    56874.318    56921.573
# 472  FLU+I+G4      28426.477    9   56870.954    56871.020    56924.175
# 484  FLU+F+G4      28162.794    27  56379.589    56380.148    56539.254
# 485  FLU+F+I+G4    28160.804    28  56377.608    56378.209    56543.187
# 497  rtREV+G4      28214.517    8   56445.034    56445.087    56492.342
# 498  rtREV+I+G4    28214.116    9   56446.231    56446.297    56499.453
# 510  rtREV+F+G4    27952.684    27  55959.368    55959.927    56119.033
# 511  rtREV+F+I+G4  27952.182    28  55960.364    55960.964    56125.943
# 523  cpREV+G4      28020.164    8   56056.329    56056.382    56103.637
# 524  cpREV+I+G4    28018.705    9   56055.409    56055.475    56108.631
# 536  cpREV+F+G4    27961.686    27  55977.373    55977.931    56137.038
# 537  cpREV+F+I+G4  27960.639    28  55977.278    55977.878    56142.856
# Akaike Information Criterion:           LG+F+G4
# Corrected Akaike Information Criterion: LG+F+G4
# Bayesian Information Criterion:         LG+G4
# Best-fit model: LG+G4 chosen according to BIC
#
# All model information printed to output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.model.gz
# CPU time for ModelFinder: 121.534 seconds (0h:2m:1s)
# Wall-clock time for ModelFinder: 63.262 seconds (0h:1m:3s)
# Generating 2000 samples for ultrafast bootstrap (seed: 900385)...
#
# NOTE: 24 MB RAM (0 GB) is required!
# Estimate model parameters (epsilon = 0.100)
# 1. Initial log-likelihood: -27901.963
# Optimal log-likelihood: -27901.961
# Gamma shape alpha: 1.824
# Parameters optimization took 1 rounds (0.088 sec)
# Computing ML distances based on estimated model parameters... 0.004 sec
# Computing BIONJ tree...
# 0.000 seconds
# Log-likelihood of BIONJ tree: -27901.961
# --------------------------------------------------------------------
# |             INITIALIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Generating 99 parsimony trees... 0.176 second
# Computing log-likelihood of 4 initial trees ... 0.109 seconds
# Current best score: -27901.961
#
# Do NNI search on 5 best initial trees
# Finish initializing candidate tree set (5)
# Current best tree score: -27901.961 / CPU time: 1.114
# Number of iterations: 5
# --------------------------------------------------------------------
# |               OPTIMIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# UPDATE BEST LOG-LIKELIHOOD: -27901.961
# UPDATE BEST LOG-LIKELIHOOD: -27901.961
# Iteration 10 / LogL: -27905.138 / Time: 0h:0m:2s
# Iteration 20 / LogL: -27908.730 / Time: 0h:0m:4s
# UPDATE BEST LOG-LIKELIHOOD: -27901.961
# Iteration 30 / LogL: -27902.413 / Time: 0h:0m:6s (0h:0m:16s left)
# Iteration 40 / LogL: -27906.764 / Time: 0h:0m:9s (0h:0m:14s left)
# UPDATE BEST LOG-LIKELIHOOD: -27901.961
# Iteration 50 / LogL: -27902.413 / Time: 0h:0m:11s (0h:0m:11s left)
# UPDATE BEST LOG-LIKELIHOOD: -27901.961
# Iteration 60 / LogL: -27901.961 / Time: 0h:0m:13s (0h:0m:9s left)
# Iteration 70 / LogL: -27904.544 / Time: 0h:0m:15s (0h:0m:6s left)
# Iteration 80 / LogL: -27905.131 / Time: 0h:0m:18s (0h:0m:4s left)
# Iteration 90 / LogL: -27901.961 / Time: 0h:0m:21s (0h:0m:2s left)
# Iteration 100 / LogL: -27906.512 / Time: 0h:0m:24s (0h:0m:0s left)
# Refining ufboot trees with NNI 1 branch...
# 100 samples done
# 200 samples done
# 300 samples done
# 400 samples done
# 500 samples done
# 600 samples done
# 700 samples done
# 800 samples done
# 900 samples done
# 1000 samples done
# 1100 samples done
# 1200 samples done
# 1300 samples done
# 1400 samples done
# 1500 samples done
# 1600 samples done
# 1700 samples done
# 1800 samples done
# 1900 samples done
# 2000 samples done
# Total 0 ufboot trees refined
# TREE SEARCH COMPLETED AFTER 101 ITERATIONS / Time: 0h:2m:22s
#
# --------------------------------------------------------------------
# |                    FINALIZING TREE SEARCH                        |
# --------------------------------------------------------------------
# Performs final model parameters optimization
# Estimate model parameters (epsilon = 0.010)
# 1. Initial log-likelihood: -27901.961
# Optimal log-likelihood: -27901.961
# Gamma shape alpha: 1.827
# Parameters optimization took 1 rounds (0.077 sec)
# BEST SCORE FOUND : -27901.961
# Empirical proportions for each category: 0.298 0.187 0.179 0.336
# Site rates printed to output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.rate
#
# Testing tree branches by SH-like aLRT with 2000 replicates...
# 0.264 sec.
# Creating bootstrap support values...
# Split supports printed to NEXUS file output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.splits.nex
# Total tree length: 4.809
#
# Total number of iterations: 101
# CPU time used for tree search: 259.046 sec (0h:4m:19s)
# Wall-clock time used for tree search: 142.425 sec (0h:2m:22s)
# Total CPU time used: 260.300 sec (0h:4m:20s)
# Total wall-clock time used: 143.167 sec (0h:2m:23s)
# UFBoot trees printed to output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.ufboot
#
# Computing bootstrap consensus tree...
# Reading input file output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.splits.nex...
# 5 taxa and 7 splits.
# Consensus tree written to output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.contree
# Reading input trees file output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.contree
# Log-likelihood of consensus tree: -27901.961
#
# Analysis results written to:
#   IQ-TREE report:                output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.iqtree
#   Maximum-likelihood tree:       output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.treefile
#   Likelihood distances:          output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.mldist
#   Site-specific rates:           output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.rate
#
# Ultrafast bootstrap approximation results written to:
#   Split support values:          output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.splits.nex
#   Consensus tree:                output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.contree
#   UFBoot trees:                  output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.ufboot
#   Screen log file:               output/21-AGS-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.log
#
# Date and Time: Fri Feb 18 05:59:28 2022

# %%
#022-USER_INPUT-broken-and-replacement-sequences

# #repair_1
# Metazoa-Ctenophora-Tentaculata-Lobata-Bolinopsidae-Mnemiopsis-leidyi_PACBIO-Mnemiopsis-leidyi-NonamEVm000133t1
# Metazoa-Ctenophora-Tentaculata-Lobata-Bolinopsidae-Mnemiopsis-leidyi_UPDATED-ML018021a-PA
# Metazoa-Ctenophora-Tentaculata-Lobata-Bolinopsidae-Mnemiopsis-leidyi_UPDATED-ML018022a-PA
# Metazoa-Ctenophora-Tentaculata-Lobata-Bolinopsidae-Mnemiopsis-leidyi_UPDATED-ML018025a-PA
# Metazoa-Ctenophora-Tentaculata-Lobata-Bolinopsidae-Mnemiopsis-leidyi_UPDATED-ML018027a-PA

# %%
#023-python-repair-broken-gene-models-with-pacbio

input_repair_ids = open( '022-USER_INPUT-broken-and-replacement-sequences', 'r' )
input_ags_broken = open( 'output/17-AGS_blastp-rgs5-piezo_X_metazoa16_basal_animals_UPDATED.aa', 'r' )
output_ags = open( 'output/23-AGS_blastp-rgs5-piezo_X_metazoa16_basal_animals_REPAIRED.aa', 'w' )
output_dropped = open( 'output/23-dropped-sequences.fasta', 'w' )

pacbio_ids = []
broken_ids = []
count = 0
for next_line in input_repair_ids:

    if next_line[ 0 ] == '#':
        count = 1

    elif count == 1:
        pacbio_id = next_line[ :-1 ]
        pacbio_ids.append( pacbio_id )
        count = 0
        
    else:
        broken_id = next_line[ :-1 ]
        broken_ids.append( broken_id )

ags_initial_seq = {}
for next_line in input_ags_broken:

    if next_line[ 0 ] == '>':

        gene_id = next_line[ 1:-1 ]
        ags_initial_seq[ gene_id ] = ''

    else:

        sequence = next_line[ :-1 ]
        ags_initial_seq[ gene_id ] = ags_initial_seq[ gene_id ] + sequence

for next_id in ags_initial_seq.keys():

    sequence = ags_initial_seq[ next_id ]

    if next_id in broken_ids:
        output = '>' + next_id + '\n' + sequence + '\n'
        output_dropped.write( output )

    elif next_id in pacbio_ids:
        output = '>' + next_id + '\n' + sequence + '\n'
        output_ags.write( output )

    elif len( next_id.split( 'Mnemiopsis' ) ) > 1:

        if len( next_id.split( 'UPDATED' ) ) > 1:
            output = '>' + next_id + '\n' + sequence + '\n'
            output_ags.write( output )
            
        else:
            output = '>' + next_id + '\n' + sequence + '\n'
            output_dropped.write( output )

    else:
        output = '>' + next_id + '\n' + sequence + '\n'
        output_ags.write( output )

input_repair_ids.close()
input_ags_broken.close()
output_ags.close()
output_dropped.close()
